# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import sklearn

# %% [markdown]
# 1.Data Understanding
# A.Read all the 3 CSV files as DataFrame and store them into 3 separate variables

# %%
data_1 = pd.read_csv('Part1+-+Normal.csv')
data_1.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
data_2 = pd.read_csv('Part1+-+Type_H.csv')
data_2.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400  Type_H
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  Type_H
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  Type_H
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  Type_H
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501  Type_H

# %%
data_3=pd.read_csv('Part1+-+Type_S.csv')
data_3.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    74.377678  32.053104  78.772013  42.324573  143.560690  56.125906  Type_S
# 1    89.680567  32.704435  83.130732  56.976132  129.955476  92.027277  Type_S
# 2    44.529051   9.433234  52.000000  35.095817  134.711772  29.106575  Type_S
# 3    77.690577  21.380645  64.429442  56.309932  114.818751  26.931841  Type_S
# 4    76.147212  21.936186  82.961502  54.211027  123.932010  10.431972  Type_S

# %% [markdown]
# B.Print Shape and columns of all the 3 DataFrames.

# %%
data_1.shape
# Out:
# (100, 7)

# %%
data_2.shape
# Out:
# (60, 7)

# %%
data_3.shape
# Out:
# (150, 7)

# %% [markdown]
# C. Compare Column names of all the 3 DataFrames and clearly write observations

# %%
data_1.columns
# Out:
# Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %%
data_2.columns
# Out:
# Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %%
data_3.columns
# Out:
# Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %% [markdown]
# All indices are same in all three dataframes.

# %% [markdown]
# D. Print DataTypes of all the 3 DataFrames

# %%
data_1.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
data_2.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
data_3.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %% [markdown]
# E.Observe and share variation in ‘Class’ feature of all the 3 DaraFrames.

# %%
data_1['Class']
# Out:
# 0     Normal
# 1     Normal
# 2     Normal
# 3     Normal
# 4     Normal
#        ...
# 95    Normal
# 96    Normal
# 97    Normal
# 98    Normal
# 99    Normal
# Name: Class, Length: 100, dtype: object

# %%
data_2['Class']
# Out:
# 0     Type_H
# 1     Type_H
# 2     Type_H
# 3     Type_H
# 4     Type_H
# 5     Type_H
# 6     Type_H
# 7     Type_H
# 8     Type_H
# 9     Type_H
# 10    Type_H
# 11    Type_H
# 12    Type_H
# 13    Type_H
# 14    Type_H
# 15    Type_H
# 16    Type_H
# 17    Type_H
# 18    Type_H
# 19    Type_H
# 20    Type_H
# 21    Type_H
# 22    Type_H
# 23    Type_H
# 24    Type_H
# 25    Type_H
# 26    Type_H
# 27    Type_H
# 28    Type_H
# 29    Type_H
# 30    Type_H
# 31    type_h
# 32    type_h
# 33    type_h
# 34    type_h
# 35    type_h
# 36    type_h
# 37    type_h
# 38    type_h
# 39    type_h
# 40    type_h
# 41    type_h
# 42    type_h
# 43    type_h
# 44    type_h
# 45    type_h
# 46    type_h
# 47    type_h
# 48    type_h
# 49    type_h
# 50    type_h
# 51    type_h
# 52    type_h
# 53    type_h
# 54    Type_H
# 55    Type_H
# 56    Type_H
# 57    Type_H
# 58    Type_H
# 59    Type_H
# Name: Class, dtype: object

# %%
data_3['Class']
# Out:
# 0      Type_S
# 1      Type_S
# 2      Type_S
# 3      Type_S
# 4      Type_S
#         ...
# 145    Type_S
# 146    Type_S
# 147    Type_S
# 148    Type_S
# 149    Type_S
# Name: Class, Length: 150, dtype: object

# %% [markdown]
# In the first dataframe there are 100 rows for the column 'Class' and all entries are either "Normal" and "Nrml
# In the second dataframe there are 60 rows for the column 'Class' and all entries are either "type_h" and "Type_H".
# In the third dataframe there are 150 rows for the column 'Class' and all entries are either "Type_S" and "tp_s".

# %% [markdown]
# 2.Data Preparation and Exploration

# %% [markdown]
# A. Unify all the variations in ‘Class’ feature for all the 3 DataFrames

# %%
data_1_uni= data_1.replace({'Class':{"Nrmal":'Normal'}})

data_1_uni.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
data_2_uni= data_2.replace({'Class':{"Type_H":'type_h'}})

data_2_uni.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400  type_h
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  type_h
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  type_h
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  type_h
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501  type_h

# %%
data_3_uni= data_3.replace({'Class':{"Type_S":'type_s' ,'tp_s':'type_s'}})

data_3_uni.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    74.377678  32.053104  78.772013  42.324573  143.560690  56.125906  type_s
# 1    89.680567  32.704435  83.130732  56.976132  129.955476  92.027277  type_s
# 2    44.529051   9.433234  52.000000  35.095817  134.711772  29.106575  type_s
# 3    77.690577  21.380645  64.429442  56.309932  114.818751  26.931841  type_s
# 4    76.147212  21.936186  82.961502  54.211027  123.932010  10.431972  type_s

# %% [markdown]
# B. Combine all the 3 DataFrames to form a single DataFrame

# %%
df_res = data_1_uni.append(data_2_uni,ignore_index = True)

df_final = df_res.append(data_3_uni,ignore_index =True)
df_final.shape
# Out:
# (310, 7)

# %% [markdown]
# C. Print 5 random samples of this DataFrame

# %%
df_samp = df_final.sample(n=5)
print(df_samp)
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 47     50.160078  -2.970024  42.000000  53.130102  131.802491  -8.290203
# 304    56.535051  14.377189  44.991547  42.157862  101.723334  25.773174
# 60     51.311771   8.875541  57.000000  42.436230  126.472258  -2.144044
# 66     51.325464  13.631223  33.258578  37.694240  131.306122   1.788870
# 219    60.753893  15.753894  43.199158  45.000000  113.053331  31.693548
#
#       Class
# 47   Normal
# 304  type_s
# 60   Normal
# 66   Normal
# 219  type_s

# %% [markdown]
# D. Print Feature-wise percentage of Null values.

# %%
null_percent = (df_final.isnull().sum())/len(df_final)
null_percent
# Out:
# P_incidence    0.0
# P_tilt         0.0
# L_angle        0.0
# S_slope        0.0
# P_radius       0.0
# S_Degree       0.0
# Class          0.0
# dtype: float64

# %% [markdown]
# E. Check 5-point summary of the new DataFrame

# %%
df_final.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %% [markdown]
# 3. Data Analysis

# %% [markdown]
# A. Visualize a heatmap to understand correlation between all features

# %%
import seaborn as sb
dataplot = sb.heatmap(df_final.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# B. Share insights on correlation
# A. Features having stronger correlation with correlation value
# ans: Features having stronger correlation are those with correlation values greater than +0.5 to 1. p_incidence and P_tilt , L_angle and P_incidence S_slope and P_incidence ,S_degree and P_incidence, S_slope and S_degree  show stronger correlation.positive values indicates positive correlation.
#
# B. Features having weaker correlation with correlation value
#
# Correlation values less than +0.5 to 0, shows weaker correlation and negative values indicate negative association. Features P_incidence and Pradius show negative association and p tilt shows weaker correlation with S_Degree.Pradius shows negative weak correlation with S_slope.
# P_radius shows significantly weaker negative relation withthe veature S_Radius.

# %% [markdown]
# C. Visualize a pairplot with 3 classes distinguished by colors and share insights

# %%
sns.pairplot(df_final,hue='Class')

# %% [markdown]
# We get the pair plot between each of the features and each feature is classified based on their Classes. what we Get to see from Each of these plots is that the Green dots represnting 'type_s' Class is dominant while orange dots indicating 'type_h' is medium in distribution and blue dots indicating Normal is mimimal.

# %% [markdown]
# D. Visualize a jointplot for ‘P_incidence’ and ‘S_slope’ and share insights

# %%
sns.jointplot( x='P_incidence',
    y='S_slope',
    data=df_final,
    kind='scatter',
    hue='Class')

# %% [markdown]
# Biomechanics attributes 'P_incidence' and 'S_Slope' shows a positive linear relationship from this jointplot. here too we observe that the type s class is predominant over the rest of the two classes.

# %% [markdown]
# E. Visualize a boxplot to check distribution of the features and share insights.

# %%
sns.boxplot(data =df_final)
# Out:
# <AxesSubplot:>

# %% [markdown]
# All of the features exhibit outliers But S_degree shows high extremity.There are also low and high outliers, which gives  an indication of which Biomechanics attributes are over- and underperforming. the Medians of the features P_incidence , L_angle and S_slope lie along the same value. while the median of P_radius is well above the other features. and that of P_tilt and S_Degree lie below the fomer three. the same is applicable for interquartile ranges also. The parameter S_degree is right skewed as the region above the median is longer .The parameter P_tilt is left skewed as the region below the median is longer . The rest of all the features show a uniform distribution (bell-shaped curve.).

# %%
df_final.groupby(["Class"]).count()
# Out:
#         P_incidence  P_tilt  L_angle  S_slope  P_radius  S_Degree
# Class
# Normal          100     100      100      100       100       100
# type_h           60      60       60       60        60        60
# type_s          150     150      150      150       150       150

# %% [markdown]
# 4. Model Building

# %% [markdown]
# A. Split data into X and Y

# %%
from sklearn.model_selection import train_test_split

X = df_final.drop('Class',axis=1)    
Y =df_final['Class']

# %%
#B. Split data into train and test with 80:20 proportion

# %%
from scipy.stats import zscore
XScaled  = X.apply(zscore)  # convert all attributes to Z scale 

XScaled.describe()
# Out:
#         P_incidence        P_tilt       L_angle       S_slope      P_radius  \
# count  3.100000e+02  3.100000e+02  3.100000e+02  3.100000e+02  3.100000e+02
# mean   1.042177e-16  2.096889e-16  1.980495e-16  2.829278e-17 -5.071212e-16
# std    1.001617e+00  1.001617e+00  1.001617e+00  1.001617e+00  1.001617e+00
# min   -1.996010e+00 -2.411664e+00 -2.047652e+00 -2.207741e+00 -3.597963e+00
# 25%   -8.173982e-01 -6.881138e-01 -8.060267e-01 -7.168418e-01 -5.423830e-01
# 50%   -1.049246e-01 -1.186061e-01 -1.278621e-01 -4.095971e-02  2.613767e-02
# 75%    7.194643e-01  4.581158e-01  5.975493e-01  7.269414e-01  5.676209e-01
# max    4.029206e+00  3.191402e+00  3.984615e+00  5.855771e+00  3.395818e+00
#
#            S_Degree
# count  3.100000e+02
# mean  -1.277204e-16
# std    1.001617e+00
# min   -9.961725e-01
# 25%   -6.585073e-01
# 50%   -3.874502e-01
# 75%    3.997679e-01
# max    1.046035e+01

# %%
x_train, x_test, y_train, y_test = train_test_split(XScaled, Y, test_size=0.2, random_state=1)
# 1 is just any random seed number

y_train.shape
# Out:
# (248,)

# %%
x_train.shape
# Out:
# (248, 6)

# %%
#C.Train a Supervised Learning Classification base model using KNN classifier.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors= 5, weights = 'distance' )

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
predicted_labels = knn.predict(x_test)


Test_Accuracy=knn.score(x_test,y_test)
Test_Accuracy
# Out:
# 0.7258064516129032

# %%
Train_Accuracy=knn.score(x_train,y_train)
Train_Accuracy
# Out:
# 1.0

# %% [markdown]
# D. Print all the possible performance metrics for both train and test data

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted_labels)
cm
# Out:
# array([[12,  2,  4],
#        [ 4,  7,  0],
#        [ 5,  2, 26]], dtype=int64)

# %%
from sklearn.metrics import classification_report
target_names = ['Normal', 'type_s', 'type_h']
print(classification_report(y_test, predicted_labels, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.57      0.67      0.62        18
#       type_s       0.64      0.64      0.64        11
#       type_h       0.87      0.79      0.83        33
#
#     accuracy                           0.73        62
#    macro avg       0.69      0.70      0.69        62
# weighted avg       0.74      0.73      0.73        62

# %% [markdown]
# 5. Performance Improvement:
#
# A. Experiment with various parameters to improve performance of the base model.

# %%
from sklearn.metrics import accuracy_score
# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors = 3)

# fitting the model
knn.fit(x_train, y_train)

# predict the response
y_pred = knn.predict(x_test)

# evaluate accuracy
print(accuracy_score(y_test, y_pred))

# instantiate learning model (k = 5)
knn = KNeighborsClassifier(n_neighbors=5)

# fitting the model
knn.fit(x_train, y_train)

# predict the response
y_pred = knn.predict(x_test)

# evaluate accuracy
print(accuracy_score(y_test, y_pred))

# instantiate learning model (k = 7)
knn = KNeighborsClassifier(n_neighbors=7)

# fitting the model
knn.fit(x_train, y_train)

# predict the response
y_pred = knn.predict(x_test)

# evaluate accuracy
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7096774193548387
# 0.7258064516129032
# 0.7580645161290323

# %%
myList = list(range(2,50))
neighbors = list(filter(lambda x: x % 2 != 0, myList))

# %%
# empty list that will hold accuracy scores
ac_scores = []

# perform accuracy metrics for values from 1,3,5....19
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    # predict the response
    y_pred = knn.predict(x_test)
    # evaluate accuracy
    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print("The optimal number of neighbors is %d" % optimal_k)
# Out:
# The optimal number of neighbors is 7

# %%
import matplotlib.pyplot as plt
# plot misclassification error vs k
plt.plot(neighbors, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
from sklearn.metrics import recall_score
#Use k=7 as the final model for prediction
knn = KNeighborsClassifier(n_neighbors = 7)

# fitting the model
knn.fit(x_train, y_train)

# predict the response
y_pred = knn.predict(x_test)

# evaluate accuracy
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred,average='macro'))
# Out:
# 0.7580645161290323
# 0.7575757575757575

# %% [markdown]
# The final model has a fair accuracy as well as recall score.
# The accuracy is the ratio between the correctly classified samples and the total number of samples in the evaluation data set. This metric is among the most commonly used in applications of ML in medicine, but is also known for being misleading in case of different class proportions, since simply assigning all samples to the prevalent class is an easy way of achieving high accuracy. The accuracy is bounded to [0, 1], where 1 represents predicting all positive and negative samples correctly, and 0 represents predicting none of the positive or negative samples correctly.
# The recall, also known as the sensitivity or True Positive Rate (TPR), denotes the rate of positive samples correctly classified, and is calculated as the ratio between correctly classified positive samples and all samples assigned to the positive class. The recall is bounded to [0, 1], where 1 represents perfectly predicting the positive class, and 0 represents incorrect prediction of all positive class samples. This metric is also regarded as being among the most important for medical studies, since it is desired to miss as few positive instances as possible, which translates to a high recall.
